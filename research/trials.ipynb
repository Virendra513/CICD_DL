# %%
d= {'Key': 'Value', "AnotherKey": "AnotherValue"}

# %%
d['Key']
# Out:
# 'Value'

# %%
d.Key()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 d.Key()
#
# AttributeError: 'dict' object has no attribute 'Key'

# %%
d.keys()
# Out:
# dict_keys(['Key', 'AnotherKey'])

# %%
from box import ConfigBox

# %%
D=ConfigBox(d)

# %%
D.Key, D.AnotherKey
# Out:
# ('Value', 'AnotherValue')

# %%
def get_predict(x:int, y:int) -> int:
    return x*y

# %%
get_predict(x=1,y=2)
# Out:
# 2

# %%
get_predict(x=2,y="2")
# Out:
# '22'

# %%
from ensure import ensure_annotations

@ensure_annotations
def get_predict(x:int, y:int) -> int:
    return x*y

# %%
get_predict(x=2,y="2")
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "e:\repo\CICD\CI_CD3_DL\env\Lib\site-packages\IPython\core\interactiveshell.py", line 3748, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\viren\AppData\Local\Temp\ipykernel_9124\3070864227.py", line 1, in <module>
#     get_predict(x=2,y="2")
#   File "e:\repo\CICD\CI_CD3_DL\env\Lib\site-packages\ensure\main.py", line 870, in __call__
#     raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
# ensure.main.EnsureError: Argument y of type <class 'str'> to <function get_predict at 0x000002498D5A6DE0> does not match annotation type <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\repo\CICD\CI_CD3_DL\env\Lib\site-packages\IPython\core\interactiveshell.py", line 2223, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\repo\CICD\CI_CD3_DL\env\Lib\site-packages\IPython\core\ultratb.py", line 1228, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\repo\CICD\CI_CD3_DL\env\Lib\site-packages\IPython\core\ultratb.py", line 1099, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\repo\CICD\CI_CD3_DL\env\Lib\site-packages\IPython\core\ultratb.py", line 907, in structured_traceback
#     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#                                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\repo\CICD\CI_CD3_DL\env\Lib\site-packages\IPython\core\ultratb.py", line 791, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\repo\CICD\CI_CD3_DL\env\Lib\site-packages\IPython\core\ultratb.py", line 667, in format_record
#     frame_info.lines,
#     ^^^^^^^^^^^^^^^^
#   File "e:\repo\CICD\CI_CD3_DL\env\Lib\site-packages\IPython\core\tbtools.py", line 356, in lines
#     return self._sd.lines  # type: ignore[misc]
#            ^^^^^^^^^^^^^^
#   File "e:\repo\CICD\CI_CD3_DL\env\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "e:\repo\CICD\CI_CD3_DL\env\Lib\site-packages\stack_data\core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "e:\repo\CICD\CI_CD3_DL\env\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "e:\repo\CICD\CI_CD3_DL\env\Lib\site-packages\stack_data\core.py", line 677, in included_pieces
#     scope_pieces = self.scope_pieces
#                    ^^^^^^^^^^^^^^^^^
#   File "e:\repo\CICD\CI_CD3_DL\env\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "e:\repo\CICD\CI_CD3_DL\env\Lib\site-packages\stack_data\core.py", line 614, in scope_pieces
#     scope_start, scope_end = self.source.line_range(self.scope)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\repo\CICD\CI_CD3_DL\env\Lib\site-packages\stack_data\core.py", line 178, in line_range
#     return line_range(self.asttext(), node)
#                       ^^^^^^^^^^^^
# AttributeError: 'Source' object has no attribute 'asttext'
